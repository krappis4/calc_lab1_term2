# %% [markdown]
# <a href="https://colab.research.google.com/github/krappis4/calc_lab1_term2/blob/main/integrals_task06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import seaborn as sns
from scipy.stats import pearsonr
import cufflinks
# hello, vita!
cufflinks.go_offline()
# %matplotlib inline
import statistics
import ssl
from decimal import Decimal
from sklearn import preprocessing
from plotly.offline import iplot
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def f(x):
    return x**3

# %%
def integral_sum(f, a, b, n, method='right'):
    dx = (b - a) / n
    x = np.linspace(a, b, n+1)
    if method == 'left':
        x_osn = x[:-1]
    elif method == 'right':
        x_osn = x[1:]
    elif method == 'middle':
        x_osn = (x[:-1] + x[1:]) / 2
    elif method == 'random':
        x_osn = np.random.uniform(low=a, high=b, size=n)
    else:
        raise ValueError("Invalid method! Choose from 'left', 'right', 'middle', or 'random'.")

    integral = np.sum(f(x_osn) * dx)
    y_osn = [f(x_osn[i]) for i in range(len(x_osn))]
    return integral, x, f(x), x_osn, y_osn

# %%
def print_(mode):
  a = 0
  b = 1
  n1 = 10
  n2 = 100
  method = mode
  integral, x, y, x_osn, y_osn = integral_sum(f, a, b, n1, method)
  integral2, x2, y2, x_osn2, y_osn2 = integral_sum(f, a, b, n2, method)

  print(f"Значение интеграла: {integral}")
  print(f"Значение интеграла 2: {integral2}")


  plt.plot(x2, y2, label='x^3 for n=100', color = "red", linewidth = 4)
  plt.bar(x_osn2, y_osn2, color="pink", edgecolor="red", alpha = 0.25, width=0.01)
  #plt.fill_between(x2[:-1], 0, y2[:-1], alpha=0.3)
  plt.plot(x, y, label='x^3 for n=10', color="black")
  plt.bar(x_osn, y_osn, color="blue", edgecolor="darkblue", alpha = 0.25, width=0.1)
  for i in x_osn[:-1]:
    plt.axvline(i, color='purple', linestyle='--')
  plt.axvline(x_osn[-1], color='purple', linestyle='--', label="equipment")
  #plt.fill_between(x[:-1], 0, y[:-1], alpha=0.3)
  plt.title('График функции и интегральной суммы')
  plt.xlabel('x')
  plt.ylabel('y')
  plt.legend()
  plt.grid(True)
  plt.show()

# %%
print_('left')
# Out:
# Значение интеграла: 0.20250000000000007
# Значение интеграла 2: 0.245025

# %%
print_('right')
# Out:
# Значение интеграла: 0.3025000000000001
# Значение интеграла 2: 0.255025

# %%
print_('middle')
# Out:
# Значение интеграла: 0.24875000000000003
# Значение интеграла 2: 0.2499875

# %%
print_('random')
# Out:
# Значение интеграла: 0.35791659495885775
# Значение интеграла 2: 0.23577639228681807
