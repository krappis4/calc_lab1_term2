# %% [markdown]
# <a href="https://colab.research.google.com/github/krappis4/calc_lab1_term2/blob/main/integrals_task19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import seaborn as sns
from scipy.stats import pearsonr
import cufflinks
# hello, vita!
cufflinks.go_offline()
# %matplotlib inline
import statistics
import ssl
from decimal import Decimal
from sklearn import preprocessing
from plotly.offline import iplot
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def f(x):
    return np.sin(2*x)  # sin(x)

# %%
def integral_sum(f, a, b, n, method='right'):
    dx = (b - a) / n
    x = np.linspace(a, b, n+1)
    if method == 'left':
        x_osn = x[:-1]
    elif method == 'right':
        x_osn = x[1:]
    elif method == 'middle':
        x_osn = (x[:-1] + x[1:]) / 2
    elif method == 'random':
        x_osn = np.random.uniform(low=a, high=b, size=n)
    else:
        raise ValueError("Invalid method! Choose from 'left', 'right', 'middle', or 'random'.")

    integral = np.sum(f(x_osn) * dx)
    y_osn = [f(x_osn[i]) for i in range(len(x_osn))]
    return integral, x, f(x), x_osn, y_osn

# %%
def print_(mode):
  a = 0
  b = np.pi
  n1 = 10
  n2 = 100
  method = mode
  integral, x, y, x_osn, y_osn = integral_sum(f, a, b, n1, method)
  integral2, x2, y2, x_osn2, y_osn2 = integral_sum(f, a, b, n2, method)

  print(f"Значение интеграла: {integral}")
  print(f"Значение интеграла 2: {integral2}")


  plt.plot(x2, y2, label='sin(2x) for n=100', color = "red")
  plt.bar(x_osn2, y_osn2, color="pink", edgecolor="red", alpha = 0.25, width=0.06)
  #plt.fill_between(x2[:-1], 0, y2[:-1], alpha=0.3)
  plt.plot(x, y, label='sin(2x) for n=10', color="black")
  plt.bar(x_osn, y_osn, color="blue", edgecolor="darkblue", alpha = 0.25, width=0.63)
  for i in x_osn[:-1]:
    plt.axvline(i, color='purple', linestyle='--')
  plt.axvline(x_osn[-1], color='purple', linestyle='--', label="equipment")
  #plt.fill_between(x[:-1], 0, y[:-1], alpha=0.3)
  plt.title('График функции и интегральной суммы')
  plt.xlabel('x')
  plt.ylabel('y')
  plt.legend()
  plt.grid(True)
  plt.show()

# %%
print_('left')
# Out:
# Значение интеграла: 1.1102230246251565e-16
# Значение интеграла 2: 6.028164079019405e-17

# %%
print_('right')
# Out:
# Значение интеграла: -1.3245797898012942e-16
# Значение интеграла 2: 5.0852234539330075e-17

# %%
print_('middle')
# Out:
# Значение интеграла: 8.326672684688674e-17
# Значение интеграла 2: 2.168404344971009e-17

# %%
print_('random')
# Out:
# Значение интеграла: 0.23291122340841858
# Значение интеграла 2: -0.04115247610880991
